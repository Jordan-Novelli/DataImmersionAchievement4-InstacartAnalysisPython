# %% [markdown]
# # DI 4.8 - Practice

# %% [markdown]
# ## Import Libraries

# %%
# Importing Libraries

import pandas as pd
import numpy as np
import os

# %%
# Import Merged DF from Prepared Data from Exercise 4.7

ords_prods_merge = pd.read_pickle(r'D:\Career Foundry\2) Data Immersion\4) Python Fundamentals for Data Analysts\DI 4.2 - Jupyter Folder\Instacart Basket Analysis\02 Data\Prepared Data\ords_prods_merged_4.7.pkl')

# %%
# Creating Path

path=r'D:\Career Foundry\2) Data Immersion\4) Python Fundamentals for Data Analysts\DI 4.2 - Jupyter Folder\Instacart Basket Analysis'

# %% [markdown]
# ## Subset

# %%
# Subset of 1,000,000 for DF

df = ords_prods_merge[:1000000]

# %%
# Checking Column Names - There is a column for Busiest Day and Busiest Days(plural) with different if-statements attached.

df.head(10)
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
# 5             0           1  Chocolate Sandwich Cookies        61
# 6             0           1  Chocolate Sandwich Cookies        61
# 7             0           1  Chocolate Sandwich Cookies        61
# 8             0           1  Chocolate Sandwich Cookies        61
# 9             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  ...  \
# 0             19     5.8          1987   3139998      138    prior  ...
# 1             19     5.8          1989   1977647      138    prior  ...
# ...

# %% [markdown]
# ## Single Aggregation

# %%
# STEP 1 (SPLIT DATA INTO GROUPS): The groupby() function will group a given dataframe by the a given column. Example product_name. 

df.groupby('product_name')

# %%
# STEP 2 (APPLY AGGREGATE) Single Aggregate - obtain descriptive stat for order_number group by department_id

df.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.447411
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.803851
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %%
# Single Aggregate - obtain mean stat for order_number group by department_id

df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.447411
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.803851
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: order_number, dtype: float64

# %% [markdown]
# ## Multiple Aggregation

# %%
# Multiple Aggregate - obtain mean/min/max with group by department_id and agg order_number

df.groupby('department_id').agg({'order_number':['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.577493   1  99
# 2                17.320781   1  96
# 3                16.084944   1  99
# 4                17.530458   1  99
# 5                14.763075   1  99
# 6                16.658449   1  99
# 7                17.031590   1  99
# 8                15.076662   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.447411   1  99
# 12               14.327957   1  99
# 13               16.548642   1  99
# 14               16.960241   1  99
# 15               16.121948   1  99
# 16               17.803851   1  99
# 17               15.593633   1  99
# 18               19.674252   1  99
# 19               16.899756   1  99
# 20               16.255442   1  99
# 21               25.535479   1  98

# %% [markdown]
# ## Aggregating Data with Transform()

# %%
# Import Merged DF from Prepared Data from Exercise 4.7 - This step in the reading wants ords_prods_merge DF

ords_prods_merge = pd.read_pickle(r'D:\Career Foundry\2) Data Immersion\4) Python Fundamentals for Data Analysts\DI 4.2 - Jupyter Folder\Instacart Basket Analysis\02 Data\Prepared Data\ords_prods_merged_4.7.pkl')

# %%
# Checking the DF

ords_prods_merge
# Out:
#           Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0                    0           1  Chocolate Sandwich Cookies        61
# 1                    0           1  Chocolate Sandwich Cookies        61
# 2                    0           1  Chocolate Sandwich Cookies        61
# 3                    0           1  Chocolate Sandwich Cookies        61
# 4                    0           1  Chocolate Sandwich Cookies        61
# ...                ...         ...                         ...       ...
# 32404854         49692       49688      Fresh Foaming Cleanser        73
# 32404855         49692       49688      Fresh Foaming Cleanser        73
# 32404856         49692       49688      Fresh Foaming Cleanser        73
# 32404857         49692       49688      Fresh Foaming Cleanser        73
# 32404858         49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  \
# ...

# %%
# STEP 3: Creating a Loyalty Flag

ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\jmesi\AppData\Local\Temp\ipykernel_2680\3831546182.py:3: FutureWarning: The provided callable <function max at 0x000001F4DA4AC4A0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0              0           1  Chocolate Sandwich Cookies        61
# 1              0           1  Chocolate Sandwich Cookies        61
# 2              0           1  Chocolate Sandwich Cookies        61
# 3              0           1  Chocolate Sandwich Cookies        61
# 4              0           1  Chocolate Sandwich Cookies        61
# 5              0           1  Chocolate Sandwich Cookies        61
# 6              0           1  Chocolate Sandwich Cookies        61
# 7              0           1  Chocolate Sandwich Cookies        61
# 8              0           1  Chocolate Sandwich Cookies        61
# 9              0           1  Chocolate Sandwich Cookies        61
# 10             0           1  Chocolate Sandwich Cookies        61
# 11             0           1  Chocolate Sandwich Cookies        61
# 12             0           1  Chocolate Sandwich Cookies        61
# ...

# %%
# Checking function

ords_prods_merge.head(100)
# Out:
#     Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0              0           1  Chocolate Sandwich Cookies        61
# 1              0           1  Chocolate Sandwich Cookies        61
# 2              0           1  Chocolate Sandwich Cookies        61
# 3              0           1  Chocolate Sandwich Cookies        61
# 4              0           1  Chocolate Sandwich Cookies        61
# ..           ...         ...                         ...       ...
# 95             0           1  Chocolate Sandwich Cookies        61
# 96             0           1  Chocolate Sandwich Cookies        61
# 97             0           1  Chocolate Sandwich Cookies        61
# 98             0           1  Chocolate Sandwich Cookies        61
# 99             0           1  Chocolate Sandwich Cookies        61
#
#     department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  ...  \
# 0              19     5.8          1987   3139998      138    prior  ...
# ...

# %%
# No limit to rows seen

pd.options.display.max_rows = None

# %%
# Checking function

ords_prods_merge.head(100)

# %%
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 24 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0_x            int64
#  1   product_id              int64
#  2   product_name            object
#  3   aisle_id                int64
#  4   department_id           int64
#  5   prices                  float64
#  6   Unnamed: 0_y            int64
#  7   order_id                int64
#  8   user_id                 int64
#  9   eval_set                object
#  10  order_number            int64
#  11  order_dow               int64
#  12  order_hour_of_day       int64
#  13  days_since_prior_order  float64
#  14  add_to_cart_order       int64
#  15  reordered               int64
#  16  _merge                  category
#  17  merge_source            category
#  18  price_range_loc         object
#  19  Busiest day             object
#  20  Busiest days            object
# ...

# %% [markdown]
# ## Deriving Columns with Loc()

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna=False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# Checking just important columns = df['column']

ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             1
# 4       764      New customer             3
# 5       777  Regular customer            16
# 6       825      New customer             3
# 7       910  Regular customer            12
# 8      1052  Regular customer            10
# 9      1052  Regular customer            15
# 10     1379      New customer             1
# 11     1480    Loyal customer            36
# 12     1480    Loyal customer            38
# 13     1480    Loyal customer            39
# 14     1494  Regular customer             6
# 15     1494  Regular customer             7
# 16     1494  Regular customer             9
# 17     1540  Regular customer             4
# 18     1540  Regular customer             5
# 19     1540  Regular customer             6
# ...
