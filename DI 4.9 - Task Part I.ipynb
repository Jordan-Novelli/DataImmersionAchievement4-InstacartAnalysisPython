# %% [markdown]
# # DI 4.9 - Part I Task

# %% [markdown]
# ## Importing Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np
import os

# %%
# Import New Customer Data Frame

df_cust = pd.read_csv(r'D:\Career Foundry\2) Data Immersion\4) Python Fundamentals for Data Analysts\DI 4.2 - Jupyter Folder\Instacart Basket Analysis\02 Data\Original Data\customers data 4.9\customers.csv', index_col = False)

# %% [markdown]
# ## Exploring Customer Data

# %%
df_cust.describe()
# Out:
#              user_id            Age   independants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %%
df_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   First Name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   Gender        206209 non-null  object
#  4   STATE         206209 non-null  object
#  5   Age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %%
df_cust.shape
# Out:
# (206209, 10)

# %%
df_cust.head(20)
# Out:
#     user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0     26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1     33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2     65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3    125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4    130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# 5    133128    Cynthia     Noble  Female        Kentucky   43    1/1/2017
# 6    152052      Chris    Walton    Male         Montana   20    1/1/2017
# 7    168851     Joseph   Hickman    Male  South Carolina   30    1/1/2017
# 8     69965     Jeremy      Vang    Male           Texas   47    1/1/2017
# 9     82820      Shawn     Chung    Male        Virginia   26    1/1/2017
# 10    26441     Gloria  Stafford  Female          Nevada   19    1/1/2017
# 11    33835      Roger     Casey    Male        Nebraska   45    1/1/2017
# ...

# %%
df_cust.tail(20)
# Out:
#         user_id   First Name      Surnam  Gender           STATE  Age  \
# 206189   193828      Russell      Travis    Male  North Carolina   46
# 206190   197067        Kathy        Bell  Female         Arizona   42
# 206191     7177      Russell   Zimmerman    Male     Mississippi   71
# 206192    61888       Joshua      Guerra    Male      New Jersey   37
# 206193   103412       Willie     Goodman    Male        Michigan   46
# 206194   189337        Shawn        Wood    Male      New Jersey   56
# 206195   205766       Amanda       Hodge  Female          Oregon   18
# 206196   139950       Gloria      Murray  Female        Colorado   45
# 206197    74598  Christopher   Velazquez    Male       Minnesota   52
# 206198    83573       Gloria      Murray  Female        Michigan   28
# 206199   179673         Adam  Villanueva    Male         Wyoming   77
# 206200   192637        Kelly    Petersen  Female         Florida   47
# ...

# %% [markdown]
# ## Wrangling (renaming and changing data types)

# %%
# Changing column names (Surnam to Last Name)

df_cust.rename(columns = {'Surnam' : 'Last Name'}, inplace = True)

# %%
# Changing column names (STATE to State)

df_cust.rename(columns = {'STATE' : 'State'}, inplace = True)

# %%
# Changing column names (n_dependants to dependants)

df_cust.rename(columns = {'n_dependants' : 'dependants'}, inplace = True)

# %%
# Checking Changes were Successful

df_cust.head()
# Out:
#    user_id First Name Last Name  Gender       State  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    independants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# Changing user_id to Integer

df_cust['user_id'] = df_cust['user_id'].astype('int')

# %%
# Checking Changes were Successful (pt1)

df_cust['user_id'].dtype
# Out:
# dtype('int32')

# %%
# Checking Changes were Successful (pt2)

df_cust.describe()
# Out:
#              user_id            Age   independants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %%
# Checking Changes were Successful (pt3)

df_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int32
#  1   First Name    206209 non-null  object
#  2   Last Name     206209 non-null  object
#  3   Gender        206209 non-null  object
#  4   State         206209 non-null  object
#  5   Age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   independants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int32(1), int64(3), object(6)
# memory usage: 14.9+ MB

# %% [markdown]
# ##### No column dropping as in Part II of this task it appears all columns will be needed for analysis. No data transposing needed.

# %% [markdown]
# ## Data Consistency Checks

# %%
# Checking for Mixed type data

for col in df_cust.columns.tolist():
  weird = (df_cust[[col]].applymap(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_cust[weird]) > 0:
    print (col)
# Out:
# First Name
# C:\Users\jmesi\AppData\Local\Temp\ipykernel_158096\1686986452.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_cust[[col]].applymap(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\jmesi\AppData\Local\Temp\ipykernel_158096\1686986452.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_cust[[col]].applymap(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\jmesi\AppData\Local\Temp\ipykernel_158096\1686986452.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_cust[[col]].applymap(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\jmesi\AppData\Local\Temp\ipykernel_158096\1686986452.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# ...

# %%
# Correcting First Name data type to str

df_cust['First Name'] = df_cust['First Name'].astype('str')

# %%
# Checking changes were successful (pt1)

df_cust['First Name'].dtype
# Out:
# dtype('O')

# %%
# Checking changes were successful (pt2)

df_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  object
#  1   First Name    206209 non-null  object
#  2   Last Name     206209 non-null  object
#  3   Gender        206209 non-null  object
#  4   State         206209 non-null  object
#  5   Age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   independants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(3), object(7)
# memory usage: 15.7+ MB

# %% [markdown]
# ##### First Name column Non-Null numerical value went from 194950 (ref. to Wrangled section) to 206209. That means 11,259 First Name entries were Mixed Type Data

# %%
# Checking for missing values

df_cust.isnull().sum()
# Out:
# user_id         0
# First Name      0
# Last Name       0
# Gender          0
# State           0
# Age             0
# date_joined     0
# independants    0
# fam_status      0
# income          0
# dtype: int64

# %% [markdown]
# ##### No missing values detected

# %%
# Checking for duplicate data

df_cust_dups = df_cust[df_cust.duplicated()]

# %%
df_cust_dups
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Last Name, Gender, State, Age, date_joined, independants, fam_status, income]
# Index: []

# %% [markdown]
# ##### No duplicate data detected

# %% [markdown]
# ## Combining Customer Data with Prepared Instacart Data

# %%
# Importing Prepared Instacart Data

ords_prods_merge = pd.read_pickle(r'D:\Career Foundry\2) Data Immersion\4) Python Fundamentals for Data Analysts\DI 4.2 - Jupyter Folder\Instacart Basket Analysis\02 Data\Prepared Data\ords_prods_merge_4.9.pkl')

# %%
# Exploring ords_prods_merge Data

ords_prods_merge
# Out:
#           Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0                    0           1  Chocolate Sandwich Cookies        61
# 1                    0           1  Chocolate Sandwich Cookies        61
# 2                    0           1  Chocolate Sandwich Cookies        61
# 3                    0           1  Chocolate Sandwich Cookies        61
# 4                    0           1  Chocolate Sandwich Cookies        61
# ...                ...         ...                         ...       ...
# 32404854         49692       49688      Fresh Foaming Cleanser        73
# 32404855         49692       49688      Fresh Foaming Cleanser        73
# 32404856         49692       49688      Fresh Foaming Cleanser        73
# 32404857         49692       49688      Fresh Foaming Cleanser        73
# 32404858         49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  \
# ...

# %%
# Exploring ords_prods_merge Data

ords_prods_merge.shape
# Out:
# (32404859, 26)

# %%
# Exploring ords_prods_merge Data

ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 26 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0_x            int64
#  1   product_id              int64
#  2   product_name            object
#  3   aisle_id                int64
#  4   department_id           int64
#  5   prices                  float64
#  6   Unnamed: 0_y            int64
#  7   order_id                int64
#  8   user_id                 int64
#  9   eval_set                object
#  10  order_number            int64
#  11  order_dow               int64
#  12  order_hour_of_day       int64
#  13  days_since_prior_order  float64
#  14  add_to_cart_order       int64
#  15  reordered               int64
#  16  _merge                  category
#  17  merge_source            category
#  18  price_range_loc         object
#  19  Busiest day             object
#  20  Busiest days            object
# ...

# %%
# Combinging ords_prods_merge with df_cust

df_merged_large = pd.merge(ords_prods_merge, df_cust, on = 'user_id', how='inner', indicator= 'merge_origin')

# %% [markdown]
# ##### I had to go back into my Wrangle section and change the 'user_id' from str to int. As I was trying to merge the two df I was getting errors that the dtype were not matching. This has reintroduced the 'user_id' back into the describe function, giving me statistical data that's not necessary.

# %%
# Checking the Inner Merge was Successful

df_merged_large.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 36 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0_x            int64
#  1   product_id              int64
#  2   product_name            object
#  3   aisle_id                int64
#  4   department_id           int64
#  5   prices                  float64
#  6   Unnamed: 0_y            int64
#  7   order_id                int64
#  8   user_id                 int64
#  9   eval_set                object
#  10  order_number            int64
#  11  order_dow               int64
#  12  order_hour_of_day       int64
#  13  days_since_prior_order  float64
#  14  add_to_cart_order       int64
#  15  reordered               int64
#  16  _merge                  category
#  17  merge_source            category
#  18  price_range_loc         object
#  19  Busiest day             object
#  20  Busiest days            object
# ...

# %%
df_merged_large.shape
# Out:
# (32404859, 36)

# %% [markdown]
# ##### In the ords_prods_merge file the shape was: (32404859, 26). Once merged with the df_cust that had a shape of: (206209, 10) the total shape became: (32404859, 36). The amount of rows did not change but the amount of columns did.

# %% [markdown]
# ## Exporting file as Pickle

# %%
path=r'D:\Career Foundry\2) Data Immersion\4) Python Fundamentals for Data Analysts\DI 4.2 - Jupyter Folder\Instacart Basket Analysis'

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'df_merged_large_pt4.9.pkl'))
