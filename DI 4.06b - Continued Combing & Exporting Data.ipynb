# %% [markdown]
# # Import Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import Combined Pickle

# %%
# Import Orders and Products Pickle Dataframe

df_ords_prods_comb = pd.read_pickle(r'D:\Career Foundry\2) Data Immersion\4) Python Fundamentals for Data Analysts\DI 4.2 - Jupyter Folder\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_combined.pkl')

# %%
# Checking Dimensions

df_ords_prods_comb.shape
# Out:
# (32434489, 12)

# %%
# Dimensions are the same as when the file was exported.

# %%
df_ords_prods_comb
# Out:
#           Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0                  0   2539329        1    prior             1          2
# 1                  0   2539329        1    prior             1          2
# 2                  0   2539329        1    prior             1          2
# 3                  0   2539329        1    prior             1          2
# 4                  0   2539329        1    prior             1          2
# ...              ...       ...      ...      ...           ...        ...
# 32434484     3421081   2977660   206209    prior            13          1
# 32434485     3421081   2977660   206209    prior            13          1
# 32434486     3421081   2977660   206209    prior            13          1
# 32434487     3421081   2977660   206209    prior            13          1
# 32434488     3421081   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %% [markdown]
# # Importing Products & Path

# %%
# Importing Cleaned Products Dataframe

df_prods_clean = pd.read_csv(r'D:\Career Foundry\2) Data Immersion\4) Python Fundamentals for Data Analysts\DI 4.2 - Jupyter Folder\Instacart Basket Analysis\02 Data\Prepared Data\prods_clean.csv', index_col = False)

# %%
df_prods_clean
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
# Creating Path

path=r'D:\Career Foundry\2) Data Immersion\4) Python Fundamentals for Data Analysts\DI 4.2 - Jupyter Folder\Instacart Basket Analysis'

# %% [markdown]
# # Combining Merged Pickle dataframe and Clean Products dataframe

# %%
# Shape check of Merged dataframe

df_ords_prods_comb.shape
# Out:
# (32434489, 12)

# %%
# Shape check of Products dataframe

df_prods_clean.shape
# Out:
# (49672, 6)

# %%
# Combining both dataframes using order_id

df_ords_prods_merged = df_prods_clean.merge(df_ords_prods_comb, on = ['product_id'], indicator = 'merge_source')

# %%
# Checking file integrity

df_ords_prods_merged
# Out:
#           Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0                    0           1  Chocolate Sandwich Cookies        61
# 1                    0           1  Chocolate Sandwich Cookies        61
# 2                    0           1  Chocolate Sandwich Cookies        61
# 3                    0           1  Chocolate Sandwich Cookies        61
# 4                    0           1  Chocolate Sandwich Cookies        61
# ...                ...         ...                         ...       ...
# 32404854         49692       49688      Fresh Foaming Cleanser        73
# 32404855         49692       49688      Fresh Foaming Cleanser        73
# 32404856         49692       49688      Fresh Foaming Cleanser        73
# 32404857         49692       49688      Fresh Foaming Cleanser        73
# 32404858         49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  \
# ...

# %%
# Merge Flag

df_ords_prods_merged['merge_source'].value_counts()
# Out:
# merge_source
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# # Exporting DF as Pickle

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merged.pkl'))
