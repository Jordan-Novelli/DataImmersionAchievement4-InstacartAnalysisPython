# %% [markdown]
# # Import Libraries

# %%
# Importing Pythong Libraries

import pandas as pd
import numpy as np
import os

# %%
# Importing Updated Dataframe

df_insta = pd.read_pickle(r'D:\Career Foundry\2) Data Immersion\4) Python Fundamentals for Data Analysts\DI 4.2 - Jupyter Folder\Instacart Basket Analysis\02 Data\Prepared Data\df_insta_4.10._pt1pkl')

# %%
df_insta.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  ...  \
# 0             19     5.8          1987   3139998      138    prior  ...
# 1             19     5.8          1989   1977647      138    prior  ...
# 2             19     5.8         11433    389851      709    prior  ...
# 3             19     5.8         12198    652770      764    prior  ...
# 4             19     5.8         12200   1813452      764    prior  ...
#
#        State  Age  date_joined  independants  fam_status  income merge_origin  \
# 0  Minnesota   81     8/1/2019             1     married   49620         both
# 1  Minnesota   81     8/1/2019             1     married   49620         both
# 2    Vermont   66    6/16/2018             2     married  158302         both
# 3  Wisconsin   40     2/9/2020             3     married   31308         both
# 4  Wisconsin   40     2/9/2020             3     married   31308         both
#
#      Region          customer_type       Profile
# 0  Region 2        active customer       elderly
# 1  Region 2        active customer       elderly
# 2  Region 1        active customer       elderly
# 3  Region 2  low-activity customer  young parent
# 4  Region 2  low-activity customer  young parent
#
# [5 rows x 39 columns]

# %%
df_insta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 39 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0_x            int64
#  1   product_id              int64
#  2   product_name            object
#  3   aisle_id                int64
#  4   department_id           int64
#  5   prices                  float64
#  6   Unnamed: 0_y            int64
#  7   order_id                int64
#  8   user_id                 int64
#  9   eval_set                object
#  10  order_number            int64
#  11  order_dow               int64
#  12  order_hour_of_day       int64
#  13  days_since_prior_order  float64
#  14  add_to_cart_order       int64
#  15  reordered               int64
#  16  _merge                  category
#  17  merge_source            category
#  18  price_range_loc         object
#  19  Busiest day             object
#  20  Busiest days            object
#  21  busiest_period_of_day   object
#  22  max_order               int64
#  23  loyalty_flag            object
#  24  spender_type            object
#  25  freq                    object
#  26  First Name              object
#  27  Last Name               object
#  28  Gender                  object
#  29  State                   object
#  30  Age                     int64
#  31  date_joined             object
#  32  independants            int64
#  33  fam_status              object
#  34  income                  int64
#  35  merge_origin            category
#  36  Region                  object
#  37  customer_type           object
#  38  Profile                 object
# dtypes: category(3), float64(2), int64(16), object(18)
# memory usage: 8.8+ GB

# %%
# Looking for orders by hour

df_insta['order_hour_of_day'].value_counts(dropna=False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
# Creating a sort for the busiest period(hr) of day

df_sorted = df_insta.sort_values(by='busiest_period_of_day')

# %%
# Analyzing the sorted data by column

df_sorted[['product_id','product_name','order_dow','order_hour_of_day','busiest_period_of_day']].head(30)
# Out:
#           product_id                                       product_name  \
# 26007751       40501                              Salsa, Verde, Roasted
# 10970206       18465        Organic Grade A Free Range Large Brown Eggs
# 10970209       18465        Organic Grade A Free Range Large Brown Eggs
# 10970210       18465        Organic Grade A Free Range Large Brown Eggs
# 10970211       18465        Organic Grade A Free Range Large Brown Eggs
# 25254296       39351  Made with Extra Virgin Olive Oil Pesto sauce w...
# 25254295       39351  Made with Extra Virgin Olive Oil Pesto sauce w...
# 25254293       39351  Made with Extra Virgin Olive Oil Pesto sauce w...
# 10970217       18465        Organic Grade A Free Range Large Brown Eggs
# 10970219       18465        Organic Grade A Free Range Large Brown Eggs
# 10970222       18465        Organic Grade A Free Range Large Brown Eggs
# 10970223       18465        Organic Grade A Free Range Large Brown Eggs
# 10970225       18465        Organic Grade A Free Range Large Brown Eggs
# 10970226       18465        Organic Grade A Free Range Large Brown Eggs
# 25254287       39351  Made with Extra Virgin Olive Oil Pesto sauce w...
# 10970231       18465        Organic Grade A Free Range Large Brown Eggs
# 10970235       18465        Organic Grade A Free Range Large Brown Eggs
# 25254279       39351  Made with Extra Virgin Olive Oil Pesto sauce w...
# 10970239       18465        Organic Grade A Free Range Large Brown Eggs
# 10970240       18465        Organic Grade A Free Range Large Brown Eggs
# 10970241       18465        Organic Grade A Free Range Large Brown Eggs
# 25254277       39351  Made with Extra Virgin Olive Oil Pesto sauce w...
# 10970203       18465        Organic Grade A Free Range Large Brown Eggs
# 10970243       18465        Organic Grade A Free Range Large Brown Eggs
# 10970202       18465        Organic Grade A Free Range Large Brown Eggs
# 25254302       39351  Made with Extra Virgin Olive Oil Pesto sauce w...
# 25254335       39351  Made with Extra Virgin Olive Oil Pesto sauce w...
# 25254334       39351  Made with Extra Virgin Olive Oil Pesto sauce w...
# 10970152       18465        Organic Grade A Free Range Large Brown Eggs
# 10970154       18465        Organic Grade A Free Range Large Brown Eggs
#
#           order_dow  order_hour_of_day busiest_period_of_day
# 26007751          5                  7        Average orders
# 10970206          4                 18        Average orders
# 10970209          6                 20        Average orders
# 10970210          2                 17        Average orders
# 10970211          0                 17        Average orders
# 25254296          4                 20        Average orders
# 25254295          4                  8        Average orders
# 25254293          1                  8        Average orders
# 10970217          0                  8        Average orders
# 10970219          3                  8        Average orders
# 10970222          0                 17        Average orders
# 10970223          0                 18        Average orders
# 10970225          6                 17        Average orders
# 10970226          6                 18        Average orders
# 25254287          3                 22        Average orders
# 10970231          0                 17        Average orders
# 10970235          3                 20        Average orders
# 25254279          1                  8        Average orders
# 10970239          1                 18        Average orders
# 10970240          0                 18        Average orders
# 10970241          5                 17        Average orders
# 25254277          6                 17        Average orders
# 10970203          3                  7        Average orders
# 10970243          1                 19        Average orders
# 10970202          6                 18        Average orders
# 25254302          1                  7        Average orders
# 25254335          3                 21        Average orders
# 25254334          3                 20        Average orders
# 10970152          1                  8        Average orders
# 10970154          4                 19        Average orders

# %%
# Group by busiest period of day and product 

sales_by_period = df_sorted.groupby(['order_hour_of_day','busiest_period_of_day','product_name']).size().reset_index(name='sales_count')

# %%
# Find the most sold product in each period

most_sold_in_period = sales_by_period.loc[sales_by_period.groupby('busiest_period_of_day')['sales_count'].idxmax()]

# %%
# Analyze data

print(most_sold_in_period)
# Out:
#         order_hour_of_day busiest_period_of_day product_name  sales_count
# 529619                 17        Average orders       Banana        30701
# 742706                 23         Fewest orders       Banana         5372
# 233498                 10           Most orders       Banana        40731

# %% [markdown]
# # Export

# %%
# Path

path=r'D:\Career Foundry\2) Data Immersion\4) Python Fundamentals for Data Analysts\DI 4.2 - Jupyter Folder\Instacart Basket Analysis'

# %%
# Exporting File

df_insta.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'df_insta_4.10_pt2.pkl'))
