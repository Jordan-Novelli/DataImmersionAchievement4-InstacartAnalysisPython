# %% [markdown]
# # DI 4.10 - Part I Task

# %% [markdown]
# ## Importing Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np
import os

# %%
# Import latest combined dataframe

df_insta = pd.read_pickle(r'D:\Career Foundry\2) Data Immersion\4) Python Fundamentals for Data Analysts\DI 4.2 - Jupyter Folder\Instacart Basket Analysis\02 Data\Prepared Data\df_merged_large_pt1_4.9.pkl')

# %%
# Creating Path

path=r'D:\Career Foundry\2) Data Immersion\4) Python Fundamentals for Data Analysts\DI 4.2 - Jupyter Folder\Instacart Basket Analysis'

# %% [markdown]
# ## Viewing the Data Frame

# %%
# Viewing DF

df_insta.head(30)
# Out:
#     Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0              0           1  Chocolate Sandwich Cookies        61
# 1              0           1  Chocolate Sandwich Cookies        61
# 2              0           1  Chocolate Sandwich Cookies        61
# 3              0           1  Chocolate Sandwich Cookies        61
# 4              0           1  Chocolate Sandwich Cookies        61
# 5              0           1  Chocolate Sandwich Cookies        61
# 6              0           1  Chocolate Sandwich Cookies        61
# 7              0           1  Chocolate Sandwich Cookies        61
# 8              0           1  Chocolate Sandwich Cookies        61
# 9              0           1  Chocolate Sandwich Cookies        61
# 10             0           1  Chocolate Sandwich Cookies        61
# 11             0           1  Chocolate Sandwich Cookies        61
# 12             0           1  Chocolate Sandwich Cookies        61
# 13             0           1  Chocolate Sandwich Cookies        61
# 14             0           1  Chocolate Sandwich Cookies        61
# 15             0           1  Chocolate Sandwich Cookies        61
# 16             0           1  Chocolate Sandwich Cookies        61
# 17             0           1  Chocolate Sandwich Cookies        61
# 18             0           1  Chocolate Sandwich Cookies        61
# 19             0           1  Chocolate Sandwich Cookies        61
# 20             0           1  Chocolate Sandwich Cookies        61
# 21             0           1  Chocolate Sandwich Cookies        61
# 22             0           1  Chocolate Sandwich Cookies        61
# 23             0           1  Chocolate Sandwich Cookies        61
# 24             0           1  Chocolate Sandwich Cookies        61
# 25             0           1  Chocolate Sandwich Cookies        61
# 26             0           1  Chocolate Sandwich Cookies        61
# 27             0           1  Chocolate Sandwich Cookies        61
# 28             0           1  Chocolate Sandwich Cookies        61
# 29             0           1  Chocolate Sandwich Cookies        61
#
#     department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  ...  \
# 0              19     5.8          1987   3139998      138    prior  ...
# 1              19     5.8          1989   1977647      138    prior  ...
# 2              19     5.8         11433    389851      709    prior  ...
# 3              19     5.8         12198    652770      764    prior  ...
# 4              19     5.8         12200   1813452      764    prior  ...
# 5              19     5.8         12372   1701441      777    prior  ...
# 6              19     5.8         13096   1871483      825    prior  ...
# 7              19     5.8         14603   1290456      910    prior  ...
# 8              19     5.8         17065    369558     1052    prior  ...
# 9              19     5.8         17070    589712     1052    prior  ...
# 10             19     5.8         22082   1798115     1379    prior  ...
# 11             19     5.8         23713    497193     1480    prior  ...
# 12             19     5.8         23715   1727826     1480    prior  ...
# 13             19     5.8         23716   2694698     1480    prior  ...
# 14             19     5.8         23937   3171753     1494    prior  ...
# 15             19     5.8         23938    186761     1494    prior  ...
# 16             19     5.8         23940    317121     1494    prior  ...
# 17             19     5.8         24740    200390     1540    prior  ...
# 18             19     5.8         24741    374436     1540    prior  ...
# 19             19     5.8         24742   2920553     1540    prior  ...
# 20             19     5.8         24743   2813049     1540    prior  ...
# 21             19     5.8         24744   2365998     1540    prior  ...
# 22             19     5.8         24745   1604797     1540    prior  ...
# 23             19     5.8         24750   2799665     1540    prior  ...
# 24             19     5.8         24751   2228851     1540    prior  ...
# 25             19     5.8         24754   2337422     1540    prior  ...
# 26             19     5.8         24755   2699008     1540    prior  ...
# 27             19     5.8         24756   1914830     1540    prior  ...
# 28             19     5.8         24757    783503     1540    prior  ...
# 29             19     5.8         24758   2500516     1540    prior  ...
#
#     First Name  Last Name  Gender                 State  Age  date_joined  \
# 0      Charles        Cox    Male             Minnesota   81     8/1/2019
# 1      Charles        Cox    Male             Minnesota   81     8/1/2019
# 2      Deborah      Glass  Female               Vermont   66    6/16/2018
# 3      Heather      Myers  Female             Wisconsin   40     2/9/2020
# 4      Heather      Myers  Female             Wisconsin   40     2/9/2020
# 5    Christina    Wallace  Female                Hawaii   51     1/4/2019
# 6          nan      Parks    Male  District of Columbia   20     5/8/2019
# 7       Sandra      Trejo  Female             Tennessee   65    7/25/2019
# 8        Ralph     Avalos    Male                Oregon   72    3/30/2018
# 9        Ralph     Avalos    Male                Oregon   72    3/30/2018
# 10      Thomas     Howard    Male                Alaska   61    3/30/2020
# 11       Randy   Franklin    Male               Alabama   19   12/28/2019
# 12       Randy   Franklin    Male               Alabama   19   12/28/2019
# 13       Randy   Franklin    Male               Alabama   19   12/28/2019
# 14     Kathryn       Hull  Female               Indiana   78    6/29/2017
# 15     Kathryn       Hull  Female               Indiana   78    6/29/2017
# 16     Kathryn       Hull  Female               Indiana   78    6/29/2017
# 17      Willie    Goodman    Male               Florida   76   11/24/2017
# 18      Willie    Goodman    Male               Florida   76   11/24/2017
# 19      Willie    Goodman    Male               Florida   76   11/24/2017
# 20      Willie    Goodman    Male               Florida   76   11/24/2017
# 21      Willie    Goodman    Male               Florida   76   11/24/2017
# 22      Willie    Goodman    Male               Florida   76   11/24/2017
# 23      Willie    Goodman    Male               Florida   76   11/24/2017
# 24      Willie    Goodman    Male               Florida   76   11/24/2017
# 25      Willie    Goodman    Male               Florida   76   11/24/2017
# 26      Willie    Goodman    Male               Florida   76   11/24/2017
# 27      Willie    Goodman    Male               Florida   76   11/24/2017
# 28      Willie    Goodman    Male               Florida   76   11/24/2017
# 29      Willie    Goodman    Male               Florida   76   11/24/2017
#
#    independants                        fam_status  income merge_origin
# 0             1                           married   49620         both
# 1             1                           married   49620         both
# 2             2                           married  158302         both
# 3             3                           married   31308         both
# 4             3                           married   31308         both
# 5             2                           married   57797         both
# 6             3  living with parents and siblings   34171         both
# 7             0                  divorced/widowed   44856         both
# 8             1                           married  153843         both
# 9             1                           married  153843         both
# 10            1                           married   42573         both
# 11            1  living with parents and siblings   32283         both
# 12            1  living with parents and siblings   32283         both
# 13            1  living with parents and siblings   32283         both
# 14            1                           married   49504         both
# 15            1                           married   49504         both
# 16            1                           married   49504         both
# 17            3                           married   53340         both
# 18            3                           married   53340         both
# 19            3                           married   53340         both
# 20            3                           married   53340         both
# 21            3                           married   53340         both
# 22            3                           married   53340         both
# 23            3                           married   53340         both
# 24            3                           married   53340         both
# 25            3                           married   53340         both
# 26            3                           married   53340         both
# 27            3                           married   53340         both
# 28            3                           married   53340         both
# 29            3                           married   53340         both
#
# [30 rows x 36 columns]

# %%
# Viewing Descriptive Information

df_insta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 36 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0_x            int64
#  1   product_id              int64
#  2   product_name            object
#  3   aisle_id                int64
#  4   department_id           int64
#  5   prices                  float64
#  6   Unnamed: 0_y            int64
#  7   order_id                int64
#  8   user_id                 int64
#  9   eval_set                object
#  10  order_number            int64
#  11  order_dow               int64
#  12  order_hour_of_day       int64
#  13  days_since_prior_order  float64
#  14  add_to_cart_order       int64
#  15  reordered               int64
#  16  _merge                  category
#  17  merge_source            category
#  18  price_range_loc         object
#  19  Busiest day             object
#  20  Busiest days            object
#  21  busiest_period_of_day   object
#  22  max_order               int64
#  23  loyalty_flag            object
#  24  spender_type            object
#  25  freq                    object
#  26  First Name              object
#  27  Last Name               object
#  28  Gender                  object
#  29  State                   object
#  30  Age                     int64
#  31  date_joined             object
#  32  independants            int64
#  33  fam_status              object
#  34  income                  int64
#  35  merge_origin            category
# dtypes: category(3), float64(2), int64(16), object(15)
# memory usage: 8.1+ GB

# %%
# Viewing size of data frame

df_insta.shape
# Out:
# (32404859, 36)

# %% [markdown]
# ### Personally Identifiable Information is present in this data frame as first name and last name. While names are the most sensitive data, the additional information could give anyone the opportunity to locate these individuals. With that being said, this customer data was fabricated for the purpose of this course.

# %% [markdown]
# ## Customer behavior in different geographic areas

# %%
# Creating a Region if-then statment

def geo_label(row):

  if row['State'] in ('Maine', 'New Hampshire', 'Vermont', 'Massachusetts', 'Rhode Island', 'Connecticut', 'New York', 'Pennsylvania', 'New Jersey'):
    return 'Region 1'
  elif row['State'] in ('Wisconsin', 'Michigan', 'Illinois', 'Indiana', 'Ohio', 'North Dakota', 'South Dakota', 'Nebraska', 'Kansas', 'Minnesota', 'Iowa', 'Missouri'):
    return 'Region 2'
  elif row['State'] in ('Delaware', 'Maryland', 'District of Columbia', 'Virginia', 'West Virginia', 'North Carolina', 'South Carolina', 'Georgia', 'Florida', 'Kentucky', 'Tennessee', 'Mississippi', 'Alabama', 'Oklahoma', 'Texas', 'Arkansas', 'Louisiana'):
    return 'Region 3'
  elif row['State'] in ('Idaho', 'Montana', 'Wyoming', 'Nevada', 'Utah', 'Colorado', 'Arizona', 'New Mexico', 'Alaska', 'Washington', 'Oregon', 'California', 'Hawaii'):
    return 'Region 4'
  else:  return 'unknown region'

# %%
# Creating Column named Region

df_insta['Region'] = df_insta.apply(geo_label, axis=1)

# %%
# Running Region function

df_insta['Region'].value_counts(dropna=False)
# Out:
# Region
# Region 3    10791885
# Region 4     8292913
# Region 2     7597325
# Region 1     5722736
# Name: count, dtype: int64

# %%
# Creating Cross tab for Region and spender_type

crosstab = pd.crosstab(df_insta['Region'], df_insta['spender_type'], dropna = False)

# %%
# Which Region spends more

crosstab.head()
# Out:
# spender_type  High spender  Low spender
# Region
# Region 1           1875170      3847566
# Region 2           2497034      5100291
# Region 3           3549625      7242260
# Region 4           2722093      5570820

# %% [markdown]
# ### Using the new Region column and the previously created spender_type column we can determin that Region 3 has to most high spenders and the most low spenders.

# %% [markdown]
# ## Excluding customers with low activity

# %%
# Exploring order data

low_active_cust = df_insta[['order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order', 'add_to_cart_order', 'max_order']]

# %%
low_active_cust
# Out:
#           order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# 0                   28          6                 11                     3.0
# 1                   30          6                 17                    20.0
# 2                    2          0                 21                     6.0
# 3                    1          3                 13                     NaN
# 4                    3          4                 17                     9.0
# ...                ...        ...                ...                     ...
# 32404854             2          0                  9                     5.0
# 32404855             1          4                 11                     NaN
# 32404856             5          3                  8                    15.0
# 32404857             9          3                 15                     5.0
# 32404858            11          1                 15                     6.0
#
#           add_to_cart_order  max_order
# 0                         5         32
# 1                         1         32
# 2                        20          5
# 3                        10          3
# 4                        11          3
# ...                     ...        ...
# 32404854                 27          6
# 32404855                  5          4
# 32404856                 12         20
# 32404857                 11         20
# 32404858                 35         11
#
# [32404859 rows x 6 columns]

# %%
# If-Then Statement to create exclusion flag

def customer_type(row):
    if row['max_order'] < 5:
        return 'low-activity customer'
    else:
        return 'active customer'

# %%
# Applying customer Type function

df_insta['customer_type'] = df_insta.apply(customer_type, axis=1)

# %%
# Running customer type function

df_insta['customer_type']
# Out:
# 0                 active customer
# 1                 active customer
# 2                 active customer
# 3           low-activity customer
# 4           low-activity customer
#                     ...
# 32404854          active customer
# 32404855    low-activity customer
# 32404856          active customer
# 32404857          active customer
# 32404858          active customer
# Name: customer_type, Length: 32404859, dtype: object

# %%
# Drop rows with low-activity customer

df_insta_ac = df_insta[df_insta['customer_type'] != 'low-activity customer']

# %%
# Checking for active customers

df_insta_ac.head(30)
# Out:
#     Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0              0           1  Chocolate Sandwich Cookies        61
# 1              0           1  Chocolate Sandwich Cookies        61
# 2              0           1  Chocolate Sandwich Cookies        61
# 5              0           1  Chocolate Sandwich Cookies        61
# 6              0           1  Chocolate Sandwich Cookies        61
# 7              0           1  Chocolate Sandwich Cookies        61
# 8              0           1  Chocolate Sandwich Cookies        61
# 9              0           1  Chocolate Sandwich Cookies        61
# 10             0           1  Chocolate Sandwich Cookies        61
# 11             0           1  Chocolate Sandwich Cookies        61
# 12             0           1  Chocolate Sandwich Cookies        61
# 13             0           1  Chocolate Sandwich Cookies        61
# 14             0           1  Chocolate Sandwich Cookies        61
# 15             0           1  Chocolate Sandwich Cookies        61
# 16             0           1  Chocolate Sandwich Cookies        61
# 17             0           1  Chocolate Sandwich Cookies        61
# 18             0           1  Chocolate Sandwich Cookies        61
# 19             0           1  Chocolate Sandwich Cookies        61
# 20             0           1  Chocolate Sandwich Cookies        61
# 21             0           1  Chocolate Sandwich Cookies        61
# 22             0           1  Chocolate Sandwich Cookies        61
# 23             0           1  Chocolate Sandwich Cookies        61
# 24             0           1  Chocolate Sandwich Cookies        61
# 25             0           1  Chocolate Sandwich Cookies        61
# 26             0           1  Chocolate Sandwich Cookies        61
# 27             0           1  Chocolate Sandwich Cookies        61
# 28             0           1  Chocolate Sandwich Cookies        61
# 29             0           1  Chocolate Sandwich Cookies        61
# 30             0           1  Chocolate Sandwich Cookies        61
# 31             0           1  Chocolate Sandwich Cookies        61
#
#     department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  ...  \
# 0              19     5.8          1987   3139998      138    prior  ...
# 1              19     5.8          1989   1977647      138    prior  ...
# 2              19     5.8         11433    389851      709    prior  ...
# 5              19     5.8         12372   1701441      777    prior  ...
# 6              19     5.8         13096   1871483      825    prior  ...
# 7              19     5.8         14603   1290456      910    prior  ...
# 8              19     5.8         17065    369558     1052    prior  ...
# 9              19     5.8         17070    589712     1052    prior  ...
# 10             19     5.8         22082   1798115     1379    prior  ...
# 11             19     5.8         23713    497193     1480    prior  ...
# 12             19     5.8         23715   1727826     1480    prior  ...
# 13             19     5.8         23716   2694698     1480    prior  ...
# 14             19     5.8         23937   3171753     1494    prior  ...
# 15             19     5.8         23938    186761     1494    prior  ...
# 16             19     5.8         23940    317121     1494    prior  ...
# 17             19     5.8         24740    200390     1540    prior  ...
# 18             19     5.8         24741    374436     1540    prior  ...
# 19             19     5.8         24742   2920553     1540    prior  ...
# 20             19     5.8         24743   2813049     1540    prior  ...
# 21             19     5.8         24744   2365998     1540    prior  ...
# 22             19     5.8         24745   1604797     1540    prior  ...
# 23             19     5.8         24750   2799665     1540    prior  ...
# 24             19     5.8         24751   2228851     1540    prior  ...
# 25             19     5.8         24754   2337422     1540    prior  ...
# 26             19     5.8         24755   2699008     1540    prior  ...
# 27             19     5.8         24756   1914830     1540    prior  ...
# 28             19     5.8         24757    783503     1540    prior  ...
# 29             19     5.8         24758   2500516     1540    prior  ...
# 30             19     5.8         24760    716845     1540    prior  ...
# 31             19     5.8         24761   1955535     1540    prior  ...
#
#     Gender                 State  Age  date_joined  independants  \
# 0     Male             Minnesota   81     8/1/2019             1
# 1     Male             Minnesota   81     8/1/2019             1
# 2   Female               Vermont   66    6/16/2018             2
# 5   Female                Hawaii   51     1/4/2019             2
# 6     Male  District of Columbia   20     5/8/2019             3
# 7   Female             Tennessee   65    7/25/2019             0
# 8     Male                Oregon   72    3/30/2018             1
# 9     Male                Oregon   72    3/30/2018             1
# 10    Male                Alaska   61    3/30/2020             1
# 11    Male               Alabama   19   12/28/2019             1
# 12    Male               Alabama   19   12/28/2019             1
# 13    Male               Alabama   19   12/28/2019             1
# 14  Female               Indiana   78    6/29/2017             1
# 15  Female               Indiana   78    6/29/2017             1
# 16  Female               Indiana   78    6/29/2017             1
# 17    Male               Florida   76   11/24/2017             3
# 18    Male               Florida   76   11/24/2017             3
# 19    Male               Florida   76   11/24/2017             3
# 20    Male               Florida   76   11/24/2017             3
# 21    Male               Florida   76   11/24/2017             3
# 22    Male               Florida   76   11/24/2017             3
# 23    Male               Florida   76   11/24/2017             3
# 24    Male               Florida   76   11/24/2017             3
# 25    Male               Florida   76   11/24/2017             3
# 26    Male               Florida   76   11/24/2017             3
# 27    Male               Florida   76   11/24/2017             3
# 28    Male               Florida   76   11/24/2017             3
# 29    Male               Florida   76   11/24/2017             3
# 30    Male               Florida   76   11/24/2017             3
# 31    Male               Florida   76   11/24/2017             3
#
#                           fam_status  income merge_origin    Region  \
# 0                            married   49620         both  Region 2
# 1                            married   49620         both  Region 2
# 2                            married  158302         both  Region 1
# 5                            married   57797         both  Region 4
# 6   living with parents and siblings   34171         both  Region 3
# 7                   divorced/widowed   44856         both  Region 3
# 8                            married  153843         both  Region 4
# 9                            married  153843         both  Region 4
# 10                           married   42573         both  Region 4
# 11  living with parents and siblings   32283         both  Region 3
# 12  living with parents and siblings   32283         both  Region 3
# 13  living with parents and siblings   32283         both  Region 3
# 14                           married   49504         both  Region 2
# 15                           married   49504         both  Region 2
# 16                           married   49504         both  Region 2
# 17                           married   53340         both  Region 3
# 18                           married   53340         both  Region 3
# 19                           married   53340         both  Region 3
# 20                           married   53340         both  Region 3
# 21                           married   53340         both  Region 3
# 22                           married   53340         both  Region 3
# 23                           married   53340         both  Region 3
# 24                           married   53340         both  Region 3
# 25                           married   53340         both  Region 3
# 26                           married   53340         both  Region 3
# 27                           married   53340         both  Region 3
# 28                           married   53340         both  Region 3
# 29                           married   53340         both  Region 3
# 30                           married   53340         both  Region 3
# 31                           married   53340         both  Region 3
#
#       customer_type
# 0   active customer
# 1   active customer
# 2   active customer
# 5   active customer
# 6   active customer
# 7   active customer
# 8   active customer
# 9   active customer
# 10  active customer
# 11  active customer
# 12  active customer
# 13  active customer
# 14  active customer
# 15  active customer
# 16  active customer
# 17  active customer
# 18  active customer
# 19  active customer
# 20  active customer
# 21  active customer
# 22  active customer
# 23  active customer
# 24  active customer
# 25  active customer
# 26  active customer
# 27  active customer
# 28  active customer
# 29  active customer
# 30  active customer
# 31  active customer
#
# [30 rows x 38 columns]

# %% [markdown]
# ## Export DF with excluded low-active customers

# %%
df_insta_ac.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'df_insta_ac_pt1_4.10.pkl'))

# %% [markdown]
# ## Customer Profiling

# %%
# Exploring customer data

customer_profiling = df_insta[['Age', 'income','independants', 'fam_status', 'department_id','product_name', 'order_dow', 'order_hour_of_day']]

# %%
# Checking profiling data

customer_profiling.head(60)
# Out:
#     Age  income  independants                        fam_status  \
# 0    81   49620             1                           married
# 1    81   49620             1                           married
# 2    66  158302             2                           married
# 3    40   31308             3                           married
# 4    40   31308             3                           married
# 5    51   57797             2                           married
# 6    20   34171             3  living with parents and siblings
# 7    65   44856             0                  divorced/widowed
# 8    72  153843             1                           married
# 9    72  153843             1                           married
# 10   61   42573             1                           married
# 11   19   32283             1  living with parents and siblings
# 12   19   32283             1  living with parents and siblings
# 13   19   32283             1  living with parents and siblings
# 14   78   49504             1                           married
# 15   78   49504             1                           married
# 16   78   49504             1                           married
# 17   76   53340             3                           married
# 18   76   53340             3                           married
# 19   76   53340             3                           married
# 20   76   53340             3                           married
# 21   76   53340             3                           married
# 22   76   53340             3                           married
# 23   76   53340             3                           married
# 24   76   53340             3                           married
# 25   76   53340             3                           married
# 26   76   53340             3                           married
# 27   76   53340             3                           married
# 28   76   53340             3                           married
# 29   76   53340             3                           married
# 30   76   53340             3                           married
# 31   76   53340             3                           married
# 32   76   53340             3                           married
# 33   76   53340             3                           married
# 34   41  122060             2                           married
# 35   41  122060             2                           married
# 36   41  122060             2                           married
# 37   67   39869             0                  divorced/widowed
# 38   67   39869             0                  divorced/widowed
# 39   67   39869             0                  divorced/widowed
# 40   67   39869             0                  divorced/widowed
# 41   67   39869             0                  divorced/widowed
# 42   37   56559             2                           married
# 43   22   46105             1                           married
# 44   30   91407             2                           married
# 45   65   32017             2                           married
# 46   37   82441             1                           married
# 47   54   53401             2                           married
# 48   73  106683             2                           married
# 49   28   96906             0                            single
# 50   28   96906             0                            single
# 51   28   96906             0                            single
# 52   28   96906             0                            single
# 53   28   96906             0                            single
# 54   80  139510             1                           married
# 55   25   29652             0                            single
# 56   36   85558             1                           married
# 57   50   40236             2                           married
# 58   77  151610             0                  divorced/widowed
# 59   60   53829             2                           married
#
#     department_id                product_name  order_dow  order_hour_of_day
# 0              19  Chocolate Sandwich Cookies          6                 11
# 1              19  Chocolate Sandwich Cookies          6                 17
# 2              19  Chocolate Sandwich Cookies          0                 21
# 3              19  Chocolate Sandwich Cookies          3                 13
# 4              19  Chocolate Sandwich Cookies          4                 17
# 5              19  Chocolate Sandwich Cookies          1                  7
# 6              19  Chocolate Sandwich Cookies          2                 14
# 7              19  Chocolate Sandwich Cookies          3                 10
# 8              19  Chocolate Sandwich Cookies          1                 20
# 9              19  Chocolate Sandwich Cookies          1                 12
# 10             19  Chocolate Sandwich Cookies          5                 11
# 11             19  Chocolate Sandwich Cookies          3                 13
# 12             19  Chocolate Sandwich Cookies          4                 13
# 13             19  Chocolate Sandwich Cookies          2                 12
# 14             19  Chocolate Sandwich Cookies          3                 10
# 15             19  Chocolate Sandwich Cookies          2                  8
# 16             19  Chocolate Sandwich Cookies          5                  8
# 17             19  Chocolate Sandwich Cookies          2                  0
# 18             19  Chocolate Sandwich Cookies          1                 21
# 19             19  Chocolate Sandwich Cookies          1                  0
# 20             19  Chocolate Sandwich Cookies          2                  2
# 21             19  Chocolate Sandwich Cookies          1                 23
# 22             19  Chocolate Sandwich Cookies          1                  3
# 23             19  Chocolate Sandwich Cookies          1                 14
# 24             19  Chocolate Sandwich Cookies          1                 14
# 25             19  Chocolate Sandwich Cookies          0                 21
# 26             19  Chocolate Sandwich Cookies          0                 22
# 27             19  Chocolate Sandwich Cookies          0                 22
# 28             19  Chocolate Sandwich Cookies          0                 20
# 29             19  Chocolate Sandwich Cookies          0                 22
# 30             19  Chocolate Sandwich Cookies          4                 22
# 31             19  Chocolate Sandwich Cookies          6                 19
# 32             19  Chocolate Sandwich Cookies          1                  1
# 33             19  Chocolate Sandwich Cookies          0                 21
# 34             19  Chocolate Sandwich Cookies          2                 12
# 35             19  Chocolate Sandwich Cookies          2                 10
# 36             19  Chocolate Sandwich Cookies          4                 17
# 37             19  Chocolate Sandwich Cookies          1                  9
# 38             19  Chocolate Sandwich Cookies          0                 13
# 39             19  Chocolate Sandwich Cookies          1                  9
# 40             19  Chocolate Sandwich Cookies          0                 17
# 41             19  Chocolate Sandwich Cookies          4                 15
# 42             19  Chocolate Sandwich Cookies          0                 14
# 43             19  Chocolate Sandwich Cookies          1                 16
# 44             19  Chocolate Sandwich Cookies          1                  8
# 45             19  Chocolate Sandwich Cookies          3                 10
# 46             19  Chocolate Sandwich Cookies          2                 20
# 47             19  Chocolate Sandwich Cookies          2                 10
# 48             19  Chocolate Sandwich Cookies          1                 14
# 49             19  Chocolate Sandwich Cookies          1                 10
# 50             19  Chocolate Sandwich Cookies          1                 10
# 51             19  Chocolate Sandwich Cookies          3                 13
# 52             19  Chocolate Sandwich Cookies          2                 11
# 53             19  Chocolate Sandwich Cookies          1                 11
# 54             19  Chocolate Sandwich Cookies          2                  7
# 55             19  Chocolate Sandwich Cookies          0                  8
# 56             19  Chocolate Sandwich Cookies          1                 16
# 57             19  Chocolate Sandwich Cookies          5                 16
# 58             19  Chocolate Sandwich Cookies          0                 13
# 59             19  Chocolate Sandwich Cookies          4                 15

# %%
# Creating profiling function

def profiling(row):
    if row['Age'] <= 17 and row['fam_status'] in ('living with parents and siblings'):
        return 'adolescent'
    elif row['Age'] >= 18 and row['fam_status'] in ('single', 'divorced/widowed', 'living with parents and siblings'):
        return 'single adult'
    elif (row['Age'] >= 18) and (row['Age'] <= 40) and row['fam_status'] in ('married') and row['independants'] >=1:
        return 'young parent'
    elif (row['Age'] >= 40) and (row['Age'] <= 64) and row['fam_status'] in ('married') and row['independants'] >=1:
        return 'parent'
    elif row['Age'] >=65:
        return 'elderly'
    else:
        return 'Other'

# %%
# Creating Column for profiling

df_insta['Profile'] = df_insta.apply(profiling, axis=1)

# %%
# Running Profile function

df_insta['Profile'].value_counts(dropna=False)
# Out:
# Profile
# single adult    9648106
# parent          9088917
# young parent    7212836
# elderly         6455000
# Name: count, dtype: int64

# %%
# Reviewing Customer Profiling Data

customer_profiling_two = df_insta[['Age', 'independants', 'fam_status', 'income', 'Profile', 'department_id','product_name', 'order_dow', 'order_hour_of_day']]

# %%
# Exploring Customer Profiling

customer_profiling_two.head(40)
# Out:
#     Age  independants                        fam_status  income       Profile  \
# 0    81             1                           married   49620       elderly
# 1    81             1                           married   49620       elderly
# 2    66             2                           married  158302       elderly
# 3    40             3                           married   31308  young parent
# 4    40             3                           married   31308  young parent
# 5    51             2                           married   57797        parent
# 6    20             3  living with parents and siblings   34171  single adult
# 7    65             0                  divorced/widowed   44856  single adult
# 8    72             1                           married  153843       elderly
# 9    72             1                           married  153843       elderly
# 10   61             1                           married   42573        parent
# 11   19             1  living with parents and siblings   32283  single adult
# 12   19             1  living with parents and siblings   32283  single adult
# 13   19             1  living with parents and siblings   32283  single adult
# 14   78             1                           married   49504       elderly
# 15   78             1                           married   49504       elderly
# 16   78             1                           married   49504       elderly
# 17   76             3                           married   53340       elderly
# 18   76             3                           married   53340       elderly
# 19   76             3                           married   53340       elderly
# 20   76             3                           married   53340       elderly
# 21   76             3                           married   53340       elderly
# 22   76             3                           married   53340       elderly
# 23   76             3                           married   53340       elderly
# 24   76             3                           married   53340       elderly
# 25   76             3                           married   53340       elderly
# 26   76             3                           married   53340       elderly
# 27   76             3                           married   53340       elderly
# 28   76             3                           married   53340       elderly
# 29   76             3                           married   53340       elderly
# 30   76             3                           married   53340       elderly
# 31   76             3                           married   53340       elderly
# 32   76             3                           married   53340       elderly
# 33   76             3                           married   53340       elderly
# 34   41             2                           married  122060        parent
# 35   41             2                           married  122060        parent
# 36   41             2                           married  122060        parent
# 37   67             0                  divorced/widowed   39869  single adult
# 38   67             0                  divorced/widowed   39869  single adult
# 39   67             0                  divorced/widowed   39869  single adult
#
#     department_id                product_name  order_dow  order_hour_of_day
# 0              19  Chocolate Sandwich Cookies          6                 11
# 1              19  Chocolate Sandwich Cookies          6                 17
# 2              19  Chocolate Sandwich Cookies          0                 21
# 3              19  Chocolate Sandwich Cookies          3                 13
# 4              19  Chocolate Sandwich Cookies          4                 17
# 5              19  Chocolate Sandwich Cookies          1                  7
# 6              19  Chocolate Sandwich Cookies          2                 14
# 7              19  Chocolate Sandwich Cookies          3                 10
# 8              19  Chocolate Sandwich Cookies          1                 20
# 9              19  Chocolate Sandwich Cookies          1                 12
# 10             19  Chocolate Sandwich Cookies          5                 11
# 11             19  Chocolate Sandwich Cookies          3                 13
# 12             19  Chocolate Sandwich Cookies          4                 13
# 13             19  Chocolate Sandwich Cookies          2                 12
# 14             19  Chocolate Sandwich Cookies          3                 10
# 15             19  Chocolate Sandwich Cookies          2                  8
# 16             19  Chocolate Sandwich Cookies          5                  8
# 17             19  Chocolate Sandwich Cookies          2                  0
# 18             19  Chocolate Sandwich Cookies          1                 21
# 19             19  Chocolate Sandwich Cookies          1                  0
# 20             19  Chocolate Sandwich Cookies          2                  2
# 21             19  Chocolate Sandwich Cookies          1                 23
# 22             19  Chocolate Sandwich Cookies          1                  3
# 23             19  Chocolate Sandwich Cookies          1                 14
# 24             19  Chocolate Sandwich Cookies          1                 14
# 25             19  Chocolate Sandwich Cookies          0                 21
# 26             19  Chocolate Sandwich Cookies          0                 22
# 27             19  Chocolate Sandwich Cookies          0                 22
# 28             19  Chocolate Sandwich Cookies          0                 20
# 29             19  Chocolate Sandwich Cookies          0                 22
# 30             19  Chocolate Sandwich Cookies          4                 22
# 31             19  Chocolate Sandwich Cookies          6                 19
# 32             19  Chocolate Sandwich Cookies          1                  1
# 33             19  Chocolate Sandwich Cookies          0                 21
# 34             19  Chocolate Sandwich Cookies          2                 12
# 35             19  Chocolate Sandwich Cookies          2                 10
# 36             19  Chocolate Sandwich Cookies          4                 17
# 37             19  Chocolate Sandwich Cookies          1                  9
# 38             19  Chocolate Sandwich Cookies          0                 13
# 39             19  Chocolate Sandwich Cookies          1                  9

# %% [markdown]
# ## Visualization of Profile Column

# %%
# Import Visual Libraries

import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# %%
# Bar Chart of Profile Column

df_insta['Profile'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Profile'>

# %%
# Saving Bar Chart

Bar_Profile = df_insta['Profile'].value_counts().plot.bar()

# %%
# Exporting Bar Chart

Bar_Profile.figure.savefig(os.path.join(path, '04 Analysis','Visualizations', 'Bar_Profile_4.10_pt1.png'))

# %% [markdown]
# ## Aggregate variables for level of usage and expenditure

# %%
# Explore Data for Usage and Expenditure

use_expend = df_insta[['user_id', 'max_order', 'loyalty_flag', 'spender_type']]

# %%
use_expend.head(30)
# Out:
#     user_id  max_order      loyalty_flag spender_type
# 0       138         32  Regular customer  Low spender
# 1       138         32  Regular customer  Low spender
# 2       709          5      New customer  Low spender
# 3       764          3      New customer  Low spender
# 4       764          3      New customer  Low spender
# 5       777         26  Regular customer  Low spender
# 6       825          9      New customer  Low spender
# 7       910         12  Regular customer  Low spender
# 8      1052         20  Regular customer  Low spender
# 9      1052         20  Regular customer  Low spender
# 10     1379         10      New customer  Low spender
# 11     1480         43    Loyal customer  Low spender
# 12     1480         43    Loyal customer  Low spender
# 13     1480         43    Loyal customer  Low spender
# 14     1494         13  Regular customer  Low spender
# 15     1494         13  Regular customer  Low spender
# 16     1494         13  Regular customer  Low spender
# 17     1540         28  Regular customer  Low spender
# 18     1540         28  Regular customer  Low spender
# 19     1540         28  Regular customer  Low spender
# 20     1540         28  Regular customer  Low spender
# 21     1540         28  Regular customer  Low spender
# 22     1540         28  Regular customer  Low spender
# 23     1540         28  Regular customer  Low spender
# 24     1540         28  Regular customer  Low spender
# 25     1540         28  Regular customer  Low spender
# 26     1540         28  Regular customer  Low spender
# 27     1540         28  Regular customer  Low spender
# 28     1540         28  Regular customer  Low spender
# 29     1540         28  Regular customer  Low spender

# %%
# Aggregating data

df_insta.groupby(['loyalty_flag', 'spender_type']).agg({'max_order':['max', 'mean', 'min']})
# Out:
#                               max_order
#                                     max       mean min
# loyalty_flag     spender_type
# Loyal customer   High spender        99  63.953996  41
#                  Low spender         99  63.994997  41
# New customer     High spender        10   6.572704   1
#                  Low spender         10   6.576135   1
# Regular customer High spender        40  23.414648  11
#                  Low spender         40  23.438541  11

# %% [markdown]
# ## Compare customer profiles, regions and departments

# %%
# Exploring profile, region and deparment

compare_insta = df_insta[['department_id','product_name', 'Region', 'Profile']]

# %%
compare_insta.head()
# Out:
#    department_id                product_name    Region       Profile
# 0             19  Chocolate Sandwich Cookies  Region 2       elderly
# 1             19  Chocolate Sandwich Cookies  Region 2       elderly
# 2             19  Chocolate Sandwich Cookies  Region 1       elderly
# 3             19  Chocolate Sandwich Cookies  Region 2  young parent
# 4             19  Chocolate Sandwich Cookies  Region 2  young parent

# %%
# Group by Region, Profile, Department

df_insta.groupby(['Region', 'Profile']).agg({'department_id':['count','min', 'mean', 'max']})
# Out:
#                       department_id
#                               count min      mean max
# Region   Profile
# Region 1 elderly            1158056   1  9.957924  21
#          parent             1613463   1  9.936104  21
#          single adult       1686415   1  9.924245  21
#          young parent       1264802   1  9.937020  21
# Region 2 elderly            1498082   1  9.873427  21
#          parent             2154690   1  9.923763  21
#          single adult       2271717   1  9.915844  21
#          young parent       1672836   1  9.938519  21
# Region 3 elderly            2145202   1  9.914084  21
#          parent             2985723   1  9.887112  21
#          single adult       3231243   1  9.924107  21
#          young parent       2429717   1  9.915832  21
# Region 4 elderly            1653660   1  9.909604  21
#          parent             2335041   1  9.960422  21
#          single adult       2458731   1  9.890423  21
#          young parent       1845481   1  9.940627  21

# %% [markdown]
# #### Looking through this data there are some instances where a particullar profile spends more (when looking at count) compared to another. There are different fluctuations and there's no indication that a single adult spends more or less than a young parent or a parent in general. Elderly also don't have a limit in the speading (looking at count) per region either.

# %%
# Compare Bar Chart step 1

comp_bar = df_insta.groupby(['Region', 'Profile']).size()

# %%
# Compare Bar Chart step 2

comp_bar = counts.unstack()

# %%
# Compare Bar Chart step 3

counts.plot.bar()
# Out:
# <Axes: xlabel='Region,Profile'>

# %%
# Saving Bar Chart

Bar_Compare = counts.plot.bar()

# %%
# Export Bar Chart

Bar_Compare.figure.savefig(os.path.join(path, '04 Analysis','Visualizations', 'Bar_Compare_4.10_pt1.png'))

# %% [markdown]
# ## Exporting Data Frame

# %%
df_insta.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'df_insta_4.10._pt1pkl'))
